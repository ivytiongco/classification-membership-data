# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
member = pd.read_csv('20200923_Membership_Data.csv')
member.head()
# Out:
#     CnBio_ID  CnMem_1_01_Total_Years CnMem_1_01_Standing  \
# 0  100060046                       3             Dropped
# 1  100060169                       3             Dropped
# 2  100060267                       3             Dropped
# 3  100060423                       3             Dropped
# 4   10017502                       4             Dropped
#
#    CnMem_1_02_Total_Years CnMem_1_02_Standing  CnMem_1_03_Total_Years  \
# 0                     NaN                 NaN                     NaN
# 1                     NaN                 NaN                     NaN
# 2                     2.0             Dropped                     1.0
# 3                     NaN                 NaN                     NaN
# 4                     3.0             Dropped                     1.0
#
#   CnMem_1_03_Standing  CnMem_1_04_Total_Years CnMem_1_04_Standing  \
# 0                 NaN                     NaN                 NaN
# 1                 NaN                     NaN                 NaN
# 2             Dropped                     NaN                 NaN
# 3                 NaN                     NaN                 NaN
# 4             Dropped                    12.0              Active
#
#    CnMem_1_05_Total_Years  ... CnMem_1_17_Total_Years  CnMem_1_17_Standing  \
# 0                     NaN  ...                    NaN                  NaN
# 1                     NaN  ...                    NaN                  NaN
# 2                     NaN  ...                    NaN                  NaN
# 3                     NaN  ...                    NaN                  NaN
# 4                     NaN  ...                    NaN                  NaN
#
#   CnMem_1_18_Total_Years  CnMem_1_18_Standing CnMem_1_19_Total_Years  \
# 0                    NaN                  NaN                    NaN
# 1                    NaN                  NaN                    NaN
# 2                    NaN                  NaN                    NaN
# 3                    NaN                  NaN                    NaN
# 4                    NaN                  NaN                    NaN
#
#    CnMem_1_19_Standing CnMem_1_20_Total_Years  CnMem_1_20_Standing  \
# 0                  NaN                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
# 2                  NaN                    NaN                  NaN
# 3                  NaN                    NaN                  NaN
# 4                  NaN                    NaN                  NaN
#
#    CnSmryAct_1_Ttal_nmbr_f_Actins  CnSmryGft_1_Total_Gift_amount
# 0                               0                         $50.00
# 1                               0                         $75.00
# 2                               0                        $275.00
# 3                               0                        $100.00
# 4                               3                      $1,972.50
#
# [5 rows x 43 columns]
